# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
import json

load_dotenv()

client_open_ai = OpenAI(api_key=os.environ.get("OPEN_AI_API_KEY"))

# %%
from opensearchpy import OpenSearch

def get_open_search_client():
    host = 'localhost'
    port = 9200

    auth = ('admin', 'admin')

    client_open_search = OpenSearch(
        hosts = [{'host': host, 'port': port}],
        http_auth = auth,
        use_ssl = True,
        verify_certs = False
    )
    return client_open_search

# %%
def open_search_quary(search_body, index_name, client_open_search, size, from_where: int=None):
    response = client_open_search.search(index=index_name, body=search_body, size=size, from_=from_where)
    if len(response['hits'])>0:
        return response['hits']['hits']
    else:
        print('There is no hits in open search DB.')
        return None

# %%
def query_with_open_AI(paper_detail):
  completion = client_open_ai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
      {"role": "system", "content": 'Generate around 2 QA pairs as well as the answer start point number for training for these information, inforamtion is seperated with \\n'},
      {"role": "user", "content": f"Abstract:{paper_detail['Abstract']}\n Article date:{paper_detail['ArticleDate']}"},
      {"role": "system", "content": 'Return a dictionary with question, answer, answer_start_point as keyword, the values of them are lists of generated results, the keyword should be presented!! Like {"question":["{question1}"...],"answer":["{answer1}"...]},"start_point":["{answer1_start_point}"...]'},
      # {"role": "system", "content": 'Every answer needs to be extractable from the context.'},
      # {"role": "system", "content": 'answer_start_point should be digits of position where the answer starts.'},
    ],
  )
  print(f"{completion.choices[0].message.content}\n")

  return json.loads(completion.choices[0].message.content)

# %%
import time
def generate_qa_pairs(paper_detail):
    data = []
    for i in paper_detail:
        paper = i['_source']
        result = query_with_open_AI(paper)
        
        questions_list=result['question']
        answers_list=result['answer']
        answers_start_point = result['start_point']

        article_title = paper['Title']
        PMID = paper['PMID']
        author = ', '.join(paper['Authors'])
        article_date = paper['ArticleDate']
        context = paper['Abstract']
        final_result = [[qu, an, an_s_p, article_title, PMID, author, context ,article_date] for qu, an, an_s_p in zip(questions_list, \
                                                                                                answers_list, answers_start_point)]
        data+=final_result
        # Avoid OpenAI blocking
        time.sleep(10)
    return data

# %%
import csv
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

index_name = 'pubmed_intelligence'

# saving_file_name = 'reformatting_testing_qa.csv'

saving_file_name = 'reformatting_testing_qa_for_evaluation.csv'

header = ['question', 'answer', 'start_point', 'article_title', 'PMID', 'author', 'context', 'article_date']

client_open_search = get_open_search_client()

search_body = {
    "query": {
        "match": {
            "_index": index_name
        }
    },
}

query_result = open_search_quary(search_body,index_name,client_open_search, 20, 8)
# Out:
# f:\Heidelberg\semester_5\INLPT\Final Project\.venv\lib\site-packages\opensearchpy\connection\http_urllib3.py:208: UserWarning: Connecting to https://localhost:9200 using SSL with verify_certs=False is insecure.
#   warnings.warn(

# %%
if query_result is not None:

    data = generate_qa_pairs(query_result)

    with open(saving_file_name, 'a+') as f:
        writer = csv.writer(f)
        # write the header
        writer.writerow(header)
        # write the data
        writer.writerows(data)
# Out:
# {
# "question": [
# "What is the diagnostic criteria for the homogenous subgroup of children in the study?",
# "How did the cognitive profiles of children with Asperger's Syndrome differ from those with autism?"
# ],
# "answer": [
# "corresponding to DSM-IV diagnosis of autism",
# "Asperger children scored higher on the Verbal Comprehension Index than on other indexes, with the lowest score found on the Processing Speed Index."
# ],
# "start_point": [
# 342,
# 1136
# ]
# }
#
# {
#   "question": [
#     "What are the two main perspectives discussed in the book chapter?",
#     "When are rational associations of selective drug inhibitors expected to become a more realistic goal according to the book chapter?"
#   ],
#   "answer": [
#     "The two main perspectives discussed in the book chapter are: 1) Future-focused perspective on devising rational associations of targeted inhibitors against distinct altered signaling-network pathways, and 2) Supporting the choice of the most convenient treatment for an individual cancer patient using artificial intelligence (AI).",
#     "Rational associations of selective drug inhibitors are expected to become a more realistic goal within the next 3-5 years according to the book chapter."
#   ],
#   "start_point": [
#     23,
#     509
#   ]
# }
#
# {
# 	"question": [
# 		"What is the condition that girls and women with classical congenital adrenal hyperplasia (CAH) experience?",
# 		"What are the two alternative hypotheses that were investigated regarding individuals with CAH?"
# 	],
# 	"answer": [
# 		"Girls and women with classical congenital adrenal hyperplasia (CAH) experience elevated androgens prenatally.",
# 		"(a) Early androgen exposure in females with CAH masculinizes (improves) spatial perception and quantitative abilities, or (b) CAH is associated with performance decrements in these domains."
# 	],
# 	"start_point": [
# 		"34",
# 		"475"
# 	]
# }
#
# {
# "question": [
# "What was the design of the study described in the abstract?",
# "How many participants were involved in the study according to the abstract?"
# ],
# "answer": [
# "A four by two between-subjects design was used in the study.",
# "One hundred and eighty nonclinical participants were assigned to the study."
# ],
# "start_point": [
# 182,
# 85
# ]
# }
#
# {
#   "question": [
#     "What is the focus of the study mentioned in the abstract?",
#     "How was Emotional Intelligence (EI) assessed in the study?"
#   ],
#   "answer": [
#     "The study focuses on assessing Emotional Intelligence (EI) and resilience in individuals belonging to an assertive outreach team for patients with serious mental illness (SMI) compared to control subjects.",
#     "EI was assessed using the German version of the Mayer-Salovey-Caruso-Emotional-Intelligence Test (MSCEIT) in the study."
#   ],
#   "start_point": [
#     "214",
#     "356"
#   ]
# }
#
# {
#   "question": [
#     "When did the Ebola epidemic that is discussed in the abstract begin?",
#     "What is the purpose of the smartphone-based contact tracing system described in the abstract?"
#   ],
#   "answer": [
#     "December 2013",
#     "To allow for real-time identification of contacts and strong accountability of contact tracers"
#   ],
#   "start_point": [
#     "164",
#     "562"
#   ]
# }
#
# {
# "question": [
# "What was the purpose of the study mentioned in the abstract?",
# "How many children were involved in the study mentioned in the abstract?"
# ],
# "answer": [
# "The purpose of the study was to determine whether smart-tablet-based neurofeedback could improve executive function in children with attention problems.",
# "Forty children (10-12 years old) were involved in the study."
# ],
# "start_point": [
# 17,
# 105
# ]
# }
#
# {
# 	"question": [
# 		"What is the main goal of the study conducted at the University Hospital of Kashani?",
# 		"What is the significance of studying axonal loss in the retina as a marker for Multiple Sclerosis (MS)?"
# 	],
# 	"answer": [
# 		"The main goal of the study conducted at the University Hospital of Kashani was to search for correlations between MRI findings, the thickness of the RNFL at the macula and optic nerve head, and WAIS-R Scores.",
# 		"Studying axonal loss in the retina is significant for MS as it can serve as a new marker for the disease."
# 	],
# 	"start_point": [
# 		385,
# 		98
# 	]
# }
#
# {"question": ["What is the primary goal of surgical reconstruction for nonsyndromic craniosynostosis?", "How many adolescent patients with sagittal nonsyndromic craniosynostosis were included in the study?", "What imaging technique was used to assess brain anatomy differences between adolescents with sagittal nonsyndromic craniosynostosis and healthy controls?"], "answer": ["Improving cognitive function", "Eight", "Deformation-based morphometry (DBM) Jacobian mapping"], "start_point": ["234", "1027", "829"]}
#
# {
# "question": [
# "What is the focus of the essay exploring Herbert Simon's principle of bounded rationality?",
# "What was the purpose behind creating the Logic Theory Machine program?"
# ],
# "answer": [
# "The early history of Herbert Simon's principle of bounded rationality in the context of his Artificial Intelligence research in the mid 1950s.",
# "To create a model of how people solved problems in elementary mathematical logic."
# ],
# "start_point": [
# 34,
# 270
# ]
# }
#
# {"question": ["What is the focus of the critical review?", "What concept helps in considering educational outcomes in the review?"],"answer": ["The critical review focuses on how the concepts of recovery and social inclusion may inform mental health nurse education curricula at Master's level.", "The concept of emotional intelligence helps consider educational outcomes in the review."],"start_point": ["22", "159"]}
#
# {
#   "question": [
#     "What is the purpose of the WRAT-3 RR subtest?",
#     "How was the test-retest reliability of the WRAT-3 RR measured in the study?"
#   ],
#   "answer": [
#     "The WRAT-3 RR is used as a measure of premorbid ability.",
#     "Intraclass correlation coefficients (ICCs) were computed using scores from baseline and follow-up assessments to determine the test-retest reliability."
#   ],
#   "start_point": [
#     "116",
#     "295"
#   ]
# }
#
# {
# "question": ["What is the relationship between preterm infants and autism spectrum disorder?", "How many preterm children were included in the study on early brain development and autism?", "What percentage of children tested positive for autism spectrum disorder in the study?", "What regions of the brain showed reduced volumes in infants diagnosed with ASD at 6.5 years?"],
# "answer": ["Increased risk of autism spectrum disorder (ASD)", "84 preterm children born at <27 weeks of gestation", "27.4%", "Temporal, occipital, insular, and limbic regions"],
# "start_point": [89, 264, 457, 939]
# }
#
# {
# "question": [
# "What is the topic of the paper discussed in the abstract?","What challenges are faced in liver segmentation from contrast-enhanced abdominal CT volumes according to the paper? "
# ],
# "answer": [
# "The topic of the paper is liver segmentation from contrast-enhanced abdominal CT volumes.","Intensity overlapping, blurred edges, large variability in liver shape, and a complex background with cluttered features are the challenges faced in liver segmentation from contrast-enhanced abdominal CT volumes."
# ],
# "start_point": ["178","375"]
# }
#
# {
#   "question": [
#     "What is the focus of the paper discussed in the abstract?",
#     "Which machine learning and artificial intelligence algorithms are highlighted in the investigation?",
#     "When was the article published?"
#   ],
#   "answer": [
#     "The paper investigates various driving style analysis solutions.",
#     "The investigation identifies Fuzzy Logic inference systems, Hidden Markov Models, and Support Vector Machines as promising algorithms.",
#     "The article was published on 2015/12/23."
#   ],
#   "start_point": [
#     "4",
#     "591",
#     "846"
#   ]
# }
#
# {"question":["What kind of communication system do plant cells possess?","How do plants acclimate to environmental stresses?"],"answer":["network-type communication system","Plants can learn from experience and memorize previous experiences in order to optimize fitness"],"start_point":[241,710]}
#
# {
#   "question": [
#     "What is the role of the GluN2B subunit of N-methyl-d-aspartate receptors in the prefrontal cortex during working memory?",
#     "How are genetic variants in the GRIN2B coding gene associated with cognitive phenotypes?",
#     "What methods were used to test the combined effect of GRIN2B genetic variants on prefrontal activity during working memory performance?"
#   ],
#   "answer": [
#     "The GluN2B subunit of N-methyl-d-aspartate receptors is crucially involved in the physiology of the prefrontal cortex during working memory.",
#     "Genetic variants in the GRIN2B coding gene have been associated with cognitive phenotypes.",
#     "A composite score was computed to combine the effects of single nucleotide polymorphisms on post-mortem prefrontal GRIN2B mRNA expression."
#   ],
#   "start_point": [
#     "BACKGROUND: The GluN2B subunit of N-methyl-d-aspartate receptors is crucially involved in the physiology of the prefrontal cortex during working memory (WM).",
#     "Consistently, genetic variants in the GluN2B coding gene (GRIN2B) have been associated with cognitive phenotypes.",
#     "Using a composite score, we tested the combined effect of GRIN2B variants on prefrontal activity during WM performance in healthy subjects."
#   ]
# }
#
# {
#   "question": [
#     "What was the objective of the study?",
#     "How many gifted adults displayed symptoms of ADHD?",
#     "What tool was used to assess ADHD symptoms in gifted adults?",
#     "How were children with high IQs assessed for ADHD symptoms?",
#     "What was the frequency of ADHD-positive cases in gifted children?",
#     "What was the significant association found in the study?"
#   ],
#   "answer": [
#     "To evaluate the presence of symptoms of attention deficit and hyperactivity disorder (ADHD) in intellectually gifted adults and children.",
#     "37.8% of gifted adults displayed symptoms of ADHD.",
#     "Adult Self-Report Scale (ASRS-18) and modified Waldrop scale for minor physical anomalies (MPAs) were used to assess ADHD symptoms in gifted adults.",
#     "Children with high IQs were assessed by teachers using the Swanson, Nolan and Pelham IV Rating Scale (SNAP-IV).",
#     "15.38% of gifted children and 7.69% of the control group displayed ADHD-positive cases.",
#     "The significant association found was between the total MPA score and ADHD in gifted adults."
#   ],
#   "start_point": [
#     "67",
#     "469",
#     "510",
#     "226",
#     "769",
#     "756"
#   ]
# }
#
# {"question": ["What is the aim of the paper regarding medicine counterfeiting?", "What analytical methods were used to authenticate the samples in the study?"], "answer": ["The aim of the paper is to explain the chosen analytical strategy to deal with six cases of counterfeits and criteria for providing information about counterfeits.", "Chemical methods including near infrared and infrared spectroscopy, capillary zone electrophoresis, and ultraviolet-visible spectrophotometry were used to authenticate the samples."], "start_point": ["288", "621"]}
#
# {
#   "question": [
#     "What is the focus of the paper on nature-inspired computing (NIC)?",
#     "What are the three primary fields that make up computational intelligence (CI)?"
#   ],
#   "answer": [
#     "physics- and biology-based approaches and algorithms",
#     "neural networks, evolutionary computing, and fuzzy logic"
#   ],
#   "start_point": [84, 270]
# }
